# %%
import csv
import json
import pandas as pd
import glob

# %%
def patientRecord(path, subjectId, chunksize=10000000):
    data = pd.read_csv(path, chunksize=chunksize) 
    data = data.get_chunk(2000)
    data = data[data["SUBJECT_ID"] == subjectId]
    return data

# %%
path = "mimic-iii-clinical-database-1.4/CHARTEVENTS.csv"
chartevent_36 = patientRecord(path,36)

# %%
chartevent_36
# Out:
#       ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID  ITEMID            CHARTTIME  \
# 0        788          36   165660      241249  223834  2134-05-12 12:00:00
# 1        789          36   165660      241249  223835  2134-05-12 12:00:00
# 2        790          36   165660      241249  224328  2134-05-12 12:00:00
# 3        791          36   165660      241249  224329  2134-05-12 12:00:00
# 4        792          36   165660      241249  224330  2134-05-12 12:00:00
# ...      ...         ...      ...         ...     ...                  ...
# 1904    2004          36   165660      241249  220179  2134-05-16 14:00:00
# 1905    2005          36   165660      241249  220180  2134-05-16 14:00:00
# 1906    2006          36   165660      241249  220181  2134-05-16 14:00:00
# 1907    2007          36   165660      241249  220210  2134-05-16 14:00:00
# 1908    2008          36   165660      241249  220277  2134-05-16 14:00:00
#
# ...

# %%
data_36 = {}

# %%
g = glob.glob("mimic-iii-clinical-database-1.4/*.csv")

for path in g:
    name = path.split("/")[-1][0:-4]
    data_36[name] = patientRecord(path,36)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/nogpu/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SUBJECT_ID'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-bb44c4aee331> in <module>
#       3 for path in g:
# ...
