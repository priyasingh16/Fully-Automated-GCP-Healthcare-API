# %%
import csv
import json
import pandas as pd
import glob

# %%
# chunk = pd.read_csv("mimic-iii-clinical-database-1.4/INPUTEVENTS_MV.csv", chunksize=10000000) 
# data = chunk.get_chunk(10000)

# %%
# filename = "mimic-iii-clinical-database-1.4/INPUTEVENTS_MV.csv"
# chunksize = 10 ** 6
# for chunk in pd.read_csv(filename, chunksize=chunksize):
#     if len(chunk[chunk["SUBJECT_ID"] == 36]) > 0:
#         print(chunk)
#         break

# %%
def patientRecord(path, subjectId, chunksize=10 ** 6):
#     data = None
    for chunk in pd.read_csv(path, chunksize=chunksize):
        data = chunk[chunk["SUBJECT_ID"] == subjectId]
        if len(data) > 0:
            break
    return data

# %%
path = "mimic-iii-clinical-database-1.4/CHARTEVENTS.csv"
chartevent_36 = patientRecord(path,36)

# %%
data_36 = {}

# %%
g = glob.glob("mimic-iii-clinical-database-1.4/*.csv")

for path in g:
    print(path)
    try:
        name = path.split("/")[-1][0:-4]
        data = patientRecord(path,36)
        data_36[name] = data
    except:
        print(name)
# Out:
# mimic-iii-clinical-database-1.4/INPUTEVENTS_CV.csv
# /home/parth/nogpu/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# mimic-iii-clinical-database-1.4/PROCEDURES_ICD.csv
# mimic-iii-clinical-database-1.4/D_CPT.csv
# D_CPT
# mimic-iii-clinical-database-1.4/LABEVENTS.csv
# mimic-iii-clinical-database-1.4/DRGCODES.csv
# mimic-iii-clinical-database-1.4/DATETIMEEVENTS.csv
# mimic-iii-clinical-database-1.4/SERVICES.csv
# mimic-iii-clinical-database-1.4/ICUSTAYS.csv
# mimic-iii-clinical-database-1.4/TRANSFERS.csv
# mimic-iii-clinical-database-1.4/D_LABITEMS.csv
# D_LABITEMS
# mimic-iii-clinical-database-1.4/D_ICD_PROCEDURES.csv
# D_ICD_PROCEDURES
# mimic-iii-clinical-database-1.4/CALLOUT.csv
# mimic-iii-clinical-database-1.4/PATIENTS.csv
# mimic-iii-clinical-database-1.4/INPUTEVENTS_MV.csv
# mimic-iii-clinical-database-1.4/ADMISSIONS.csv
# mimic-iii-clinical-database-1.4/DIAGNOSES_ICD.csv
# mimic-iii-clinical-database-1.4/MICROBIOLOGYEVENTS.csv
# mimic-iii-clinical-database-1.4/NOTEEVENTS.csv
# /home/parth/nogpu/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# mimic-iii-clinical-database-1.4/D_ITEMS.csv
# D_ITEMS
# mimic-iii-clinical-database-1.4/CAREGIVERS.csv
# CAREGIVERS
# mimic-iii-clinical-database-1.4/PROCEDUREEVENTS_MV.csv
# mimic-iii-clinical-database-1.4/PRESCRIPTIONS.csv
# mimic-iii-clinical-database-1.4/CHARTEVENTS.csv
# mimic-iii-clinical-database-1.4/CPTEVENTS.csv
# /home/parth/nogpu/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3249: DtypeWarning: Columns (4,5,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
# mimic-iii-clinical-database-1.4/OUTPUTEVENTS.csv
# mimic-iii-clinical-database-1.4/D_ICD_DIAGNOSES.csv
# D_ICD_DIAGNOSES

# %%
data_36.keys()
# Out:
# dict_keys(['INPUTEVENTS_CV', 'PROCEDURES_ICD', 'LABEVENTS', 'DRGCODES', 'DATETIMEEVENTS', 'SERVICES', 'ICUSTAYS', 'TRANSFERS', 'CALLOUT', 'PATIENTS', 'INPUTEVENTS_MV', 'ADMISSIONS', 'DIAGNOSES_ICD', 'MICROBIOLOGYEVENTS', 'NOTEEVENTS', 'PROCEDUREEVENTS_MV', 'PRESCRIPTIONS', 'CHARTEVENTS', 'CPTEVENTS', 'OUTPUTEVENTS'])

# %%
data_36["INPUTEVENTS_CV"]
# Out:
#         ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  ITEMID  \
# 146883  147298          36  182104.0    280987.0  2131-05-04 22:00:00   30056
# 146884  147299          36  182104.0    280987.0  2131-05-05 00:00:00   30056
# 146885  147300          36  182104.0    280987.0  2131-05-05 03:00:00   30056
# 146886  147301          36  182104.0    280987.0  2131-05-05 09:00:00   30056
# 146887  147302          36  182104.0    280987.0  2131-05-05 12:00:00   30056
# 600294  571693          36  182104.0    280987.0  2131-05-04 18:00:00   30013
# 600295  571694          36  182104.0    280987.0  2131-05-04 20:00:00   30013
# 600296  571695          36  182104.0    280987.0  2131-05-05 09:00:00   30013
# 821628  782258          36  122659.0    211200.0  2131-05-17 04:45:00   30021
# 821629  782259          36  122659.0    211200.0  2131-05-17 05:00:00   30021
# 821630  782260          36  122659.0    211200.0  2131-05-17 08:00:00   30021
# 821631  782261          36  122659.0    211200.0  2131-05-17 17:30:00   30021
# 821632  782262          36  122659.0    211200.0  2131-05-17 21:00:00   30021
# 821633  782263          36  122659.0    211200.0  2131-05-18 22:30:00   30021
# 821634  782264          36  122659.0    211200.0  2131-05-18 23:30:00   30021
# 821635  782265          36  122659.0    211200.0  2131-05-22 07:00:00   30021
# 830832  782248          36  182104.0    280987.0  2131-05-04 15:45:00   30021
# 830833  782249          36  182104.0    280987.0  2131-05-04 16:00:00   30021
# 830834  782250          36  182104.0    280987.0  2131-05-04 16:30:00   30021
# 830835  782251          36  182104.0    280987.0  2131-05-04 17:00:00   30021
# 830836  782252          36  182104.0    280987.0  2131-05-04 18:00:00   30021
# 830837  782253          36  182104.0    280987.0  2131-05-04 21:00:00   30021
# 830838  782254          36  182104.0    280987.0  2131-05-04 22:00:00   30021
# 830839  782255          36  182104.0    280987.0  2131-05-05 05:00:00   30021
# 830840  782256          36  122659.0    211200.0  2131-05-17 02:00:00   30021
# 830841  782257          36  122659.0    211200.0  2131-05-17 03:00:00   30021
# 857092  901892          36  122659.0    211200.0  2131-05-17 07:15:00   30101
# 857093  901893          36  122659.0    211200.0  2131-05-17 08:00:00   30101
#
#         AMOUNT AMOUNTUOM  RATE  RATEUOM  ...   ORDERID  LINKORDERID  STOPPED  \
# 146883    30.0        ml   NaN      NaN  ...   7442931      7442931      NaN
# 146884     NaN        ml   NaN      NaN  ...   8624517      7442931      NaN
# 146885     NaN        ml   NaN      NaN  ...   3517759      7442931      NaN
# 146886   240.0        ml   NaN      NaN  ...   9832044      7442931      NaN
# 146887   240.0        ml   NaN      NaN  ...   9894203      7442931      NaN
# 600294   100.0        ml   NaN      NaN  ...   7102302      7102302      NaN
# 600295   200.0        ml   NaN      NaN  ...    215646      7102302      NaN
# 600296   200.0        ml   NaN      NaN  ...   3876511      7102302      NaN
# 821628   175.0        ml   NaN      NaN  ...  10381630      7485272      NaN
# 821629    25.0        ml   NaN      NaN  ...   4429360      7485272      NaN
# 821630     NaN        ml   NaN      NaN  ...   2958103      7485272  Stopped
# 821631   500.0        ml   NaN      NaN  ...   2435268      7485272      NaN
# 821632     0.0       NaN   NaN      NaN  ...    785174      7485272    D/C'd
# 821633   500.0        ml   NaN      NaN  ...   3052689      3052689      NaN
# 821634   500.0        ml   NaN      NaN  ...   5262827      3052689      NaN
# 821635     0.0       NaN   NaN      NaN  ...  11375957      3052689    D/C'd
# 830832   400.0        ml   NaN      NaN  ...   7485272      7485272      NaN
# 830833   600.0        ml   NaN      NaN  ...   1950375      7485272      NaN
# 830834   500.0        ml   NaN      NaN  ...   5426834      7485272      NaN
# 830835   500.0        ml   NaN      NaN  ...    737803      7485272      NaN
# 830836   500.0        ml   NaN      NaN  ...  11813273      7485272      NaN
# 830837   250.0        ml   NaN      NaN  ...   2544325      7485272      NaN
# 830838   250.0        ml   NaN      NaN  ...   5001710      7485272      NaN
# 830839   500.0        ml   NaN      NaN  ...   5827821      7485272      NaN
# 830840     0.0        ml   NaN      NaN  ...   8366144      7485272      NaN
# 830841   100.0        ml   NaN      NaN  ...   4070400      7485272      NaN
# 857092  1000.0        ml   NaN      NaN  ...   5311375      5311375      NaN
# 857093     0.0       NaN   NaN      NaN  ...   8475099      5311375    D/C'd
#
#         NEWBOTTLE ORIGINALAMOUNT  ORIGINALAMOUNTUOM     ORIGINALROUTE  \
# 146883        NaN            NaN                 ml              Oral
# 146884        NaN            NaN                 ml              Oral
# 146885        NaN            NaN                 ml              Oral
# 146886        NaN            NaN                 ml              Oral
# 146887        NaN            NaN                 ml              Oral
# 600294        NaN          100.0                 ml  Intravenous Push
# 600295        NaN          100.0                 ml  Intravenous Push
# 600296        NaN          100.0                 ml  Intravenous Push
# 821628        NaN            NaN                 ml  Intravenous Push
# 821629        NaN            NaN                 ml  Intravenous Push
# 821630        NaN            NaN                 ml  Intravenous Push
# 821631        NaN            NaN                 ml  Intravenous Push
# 821632        NaN            NaN                 ml  Intravenous Push
# 821633        NaN            NaN                 ml  Intravenous Push
# 821634        NaN            NaN                 ml  Intravenous Push
# 821635        NaN            NaN                 ml  Intravenous Push
# 830832        NaN            NaN                 ml  Intravenous Push
# 830833        NaN            NaN                 ml  Intravenous Push
# 830834        NaN            NaN                 ml  Intravenous Push
# 830835        NaN            NaN                 ml  Intravenous Push
# 830836        NaN            NaN                 ml  Intravenous Push
# 830837        NaN            NaN                 ml  Intravenous Push
# 830838        NaN            NaN                 ml  Intravenous Push
# 830839        NaN            NaN                 ml  Intravenous Push
# 830840        1.0            NaN                 ml  Intravenous Push
# 830841        NaN            NaN                 ml  Intravenous Push
# 857092        NaN            NaN                 ml  Intravenous Push
# 857093        NaN            NaN                 ml  Intravenous Push
#
#        ORIGINALRATE ORIGINALRATEUOM  ORIGINALSITE
# 146883          NaN             NaN           NaN
# 146884          NaN             NaN           NaN
# 146885          NaN             NaN           NaN
# 146886          NaN             NaN           NaN
# 146887          NaN             NaN           NaN
# 600294          NaN             NaN           NaN
# 600295          NaN             NaN           NaN
# 600296          NaN             NaN           NaN
# 821628          NaN             NaN           NaN
# 821629          NaN             NaN           NaN
# 821630          NaN             NaN           NaN
# 821631          NaN             NaN           NaN
# 821632          NaN             NaN           NaN
# 821633          NaN             NaN           NaN
# 821634          NaN             NaN           NaN
# 821635          NaN             NaN           NaN
# 830832          NaN             NaN           NaN
# 830833          NaN             NaN           NaN
# 830834          NaN             NaN           NaN
# 830835          NaN             NaN           NaN
# 830836          NaN             NaN           NaN
# 830837          NaN             NaN           NaN
# 830838          NaN             NaN           NaN
# 830839          NaN             NaN           NaN
# 830840          NaN             NaN           NaN
# 830841          NaN             NaN           NaN
# 857092          NaN             NaN           NaN
# 857093          NaN             NaN           NaN
#
# [28 rows x 22 columns]
